# %% [markdown]
# # OneR

# %% [markdown]
# ![image.png](attachment:0b15633c-19c8-42c6-9b1b-d192a30d07b2.png)
#
# OneR = OneRules significa criar uma regra
#
# ![image.png](attachment:40111a6f-dccd-4609-9a1e-aab654658d31.png)
#
#
#
# `11 se nenhum então baixo 3 - se nenhum então moderado 2 - se nenhum então alto 6 ---- erro = 5 / 11
# 3 se adequada então baixo 2 - se adequada então moderado 1 - se adequada então alto 0 ----- erro = 1 / 3         erro total = 6 / 14`
#
#
# #### <code style='color:red'> OneR escolherá o que tem o menor erro </code>
# ![image.png](attachment:8ba8ab48-d4de-49c2-8626-f7b6c9dcfe51.png)

# %% [markdown]
# # Prism

# %% [markdown]
# SE ? ENTÃO RISCO = ALTO `LEVANDO CONSIDERAÇÃO SOMENTE NO ALTO POR EXEMPLO`
