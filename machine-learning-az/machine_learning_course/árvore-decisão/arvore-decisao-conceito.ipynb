# %%
"""
    Árvore de decisão
    faz a leitura da base de dados original com o objetivo de montar uma arvore de decisão.
"""

# %% [markdown]
# Calculo de entropia e ganho de informação
# #### Cálculo para descobrir os melhores atributos para serem colocados no ramo superior em uma árvore de decisão
#
#
# ![image.png](attachment:28c58615-83b6-4270-a1b7-f51260f7bbf9.png)|

# %% [markdown]
# ### Passos para fazer o cálculo
#
# Cálculo Entropy
#
# ![image.png](attachment:e76166e5-6279-4053-a1f9-acb691da420e.png)
#
# #### <code style="color: red"> Cálculo realizado no atributo história de crédito. Para saber dos outros deve ser feito o mesmo cálculo.</code>
# #### <code style="color: red"> O que tiver como resultado final maior é o melhor para usar como ramo superior de uma arvore de decisão. </code>
#
# ![image.png](attachment:e061733d-209f-492c-9740-43d6a0db4266.png)
# ![image.png](attachment:de437442-835a-478a-a47a-5182681a0760.png)
# ![image.png](attachment:e9eb4893-a438-4706-80ba-0298cbe92b98.png)

# %% [markdown]
# # MAIS CONCEITOS
#
# FORMAS DE VER A DIVISÃO EM ÁRVORES DE DECISÃO
# ![image.png](attachment:75057ad6-43d0-4eff-8cd3-5b9c4d27da87.png)
#
# <code style='color: green'> UMAS DAS TÉCNICAS UTILIZADAS É MONTAR UMA ÁRVORE DE DECISÃO COMPLETA, E DEPOIS PODÁ-LAS </code>

# %% [markdown]
# ![image.png](attachment:4a02d57a-fbfe-415e-9e50-631f42191c03.png)
#
# ### OVERFITTING = Quando a treinamento de máquina aprende demais com os dados de treinamento
#
# ## VANTAGENS DE DESVANTAGENS DE ÁRVORES DE DECISÃO
# ![image.png](attachment:da6bf6bb-2b69-43d4-971f-ab84df8d420b.png)
